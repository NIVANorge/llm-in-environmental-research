# %%
import os
import re
import json
import time
import pandas as pd
import vertexai
from vertexai.generative_models import GenerativeModel, GenerationConfig

# BILLING: https://ai.google.dev/pricing

DATASET = 'data/abstracts-500'
GET_DOI = False

MODEL_VERSION = "gemini-2.0-flash"
PROMPT = 'v1_prompt'

instruction_file = f'./{PROMPT}.txt'
dataset_file = f'../{DATASET}.xlsx'
output_file = f'./results/gemini_2025/{DATASET}__{PROMPT}__output.xlsx'

# %%
PROJECT_ID = "<GCP-PROJECT-ID-HERE>"
vertexai.init(project=PROJECT_ID, location="europe-west1")

df = pd.read_excel(dataset_file)

with open(instruction_file, 'r') as file:
    instructions = file.read()

# Print the instructions that will be fed to Gemini
print(instructions)

model = GenerativeModel(model_name=MODEL_VERSION, system_instruction=instructions)
# Out:
# I am screening papers for a systematic literature review.
# The topic of the systematic review is assessing links between urban greenspaces and mental health in low- and middle-income countries. The general urban population of upper/lower-middle-income and low-income countries, as defined by OECD’s Development Assistance Committee (DAC) is included. Studies from high-income countries are excluded.
# The study should focus exclusively on this topic.
#
# Decide if the following article should be included or excluded from the systematic review. I give the title and abstract of the article as input.
#
# Please respond with a plain JSON, without any formatting or backticks, that adheres to the following format:
# {
#   "verdict": "<your verdict here, either 'include' or 'exclude'>",
#   "explanation": "<detailed explanation to justify your verdict here>",
#   "confidence": "<confidence level of your decision here>"
# }
#
# Be lenient. I prefer including papers by mistake rather than excluding them by mistake.

# %%
def classify_paper(paper):

    response = model.generate_content(
        paper,
        generation_config = GenerationConfig(
            temperature=0.0
        )
    )
    response_content = response.text
    
    # Clean markdown code block if present
    cleaned_response = re.sub(r"^```(?:json)?\n|```$", "", response_content.strip(), flags=re.IGNORECASE | re.MULTILINE)

    return cleaned_response

# %%
def update_output_file(output_file, new_row):

    # Define the columns for the DataFrame
    columns = ["ID", "Include/exclude", "Gemini verdict", "Gemini explanation", "Gemini confidence", "Title", "Authors", "Abstract"]
    
    # Check if the file exists
    if not os.path.exists(output_file):
        # Create a new DataFrame with the headers and save it to a new Excel file
        df = pd.DataFrame(columns=columns)

        # Append the new row to the DataFrame using concat
        df = pd.concat([df, new_row], ignore_index=True)
        
        df.to_excel(output_file, index=False)
        print(f"Created new file: {output_file} and added the first row.")
    else:
        # Load the existing file into a DataFrame
        df = pd.read_excel(output_file)

        # Append the new row to the DataFrame using concat
        df = pd.concat([df, new_row], ignore_index=True)
    
        # Save the updated DataFrame back to the Excel file
        df.to_excel(output_file, index=False)
        # print("New row added to the existing file.")

# %%
true_positives = 0
true_negatives = 0
false_positives = 0
false_negatives = 0

# Record the start time
start_time = time.time()
total_rows_number = len(df)

# Iterate over the rows and print the content
for index, row in df.iterrows():

    r = row.to_dict()
    paper = f"Authors: {r['AUTHOR']}\n\nTitle: {r['TITLE']}\n\nAbstract: {r['ABSTRACT']}"
    # print(f"Paper ID {r['ID']}: {r['Title']}\n")
    print(f"Screening paper {index + 1}/{total_rows_number}")

    # Attempt to classify the paper and handle potential issues
    try:
        response_content = classify_paper(paper)

        # print(f"Raw response for paper ID {r['ID']}:\n{response_content!r}")

        # Attempt to parse the JSON response
        answer_dict = json.loads(response_content)
        
    except json.JSONDecodeError as e:
        # print(f"Failed to decode JSON response for paper ID {r['ID']}: {e}")
        # continue  # Skip this row and move to the next one if JSON parsing fails
        raise RuntimeError(f"Failed to decode JSON response for paper ID {r['ID']}: {e}")
    
    new_row = pd.DataFrame([{
        "ID": r['ID'],
        "Include/exclude": r['Include/exclude'],
        "Gemini verdict": answer_dict['verdict'],
        "Gemini explanation": answer_dict['explanation'],
        "Gemini confidence": answer_dict['confidence'],
        "Title": r['TITLE'],
        "Authors": r['AUTHOR'],
        "Abstract": r['ABSTRACT']
    }])

    update_output_file(output_file, new_row)

    if r['Include/exclude'] == answer_dict['verdict'] == "include":
        true_positives += 1
    elif r['Include/exclude'] == answer_dict['verdict'] == "exclude":
        true_negatives += 1
    elif r['Include/exclude'] == "include" and answer_dict['verdict'] == "exclude":
        false_negatives += 1
    elif r['Include/exclude'] == "exclude" and answer_dict['verdict'] == "include":
        false_positives += 1
        

# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

print(f"\n\nThis paper screening took {elapsed_time:.1f} seconds")
print(f"The screening included {true_positives + true_negatives + false_positives + false_negatives} papers, out of which {true_positives + true_negatives} were correctly classified")
print(f"True positives: {true_positives}")
print(f"True negatives: {true_negatives}")
print(f"False positives: {false_positives}")
print(f"False negatives: {false_negatives}")
# Out:
# Screening paper 1/500
# Created new file: ./max/results/gemini_2025/correct-abstracts-500__v1_balanced-prompt-without-examples__output.xlsx and added the first row.
# Screening paper 2/500
# Screening paper 3/500
# Screening paper 4/500
# Screening paper 5/500
# Screening paper 6/500
# Screening paper 7/500
# Screening paper 8/500
# Screening paper 9/500
# Screening paper 10/500
# Screening paper 11/500
# Screening paper 12/500
# Screening paper 13/500
# Screening paper 14/500
# Screening paper 15/500
# Screening paper 16/500
# Screening paper 17/500
# Screening paper 18/500
# Screening paper 19/500
# Screening paper 20/500
# Screening paper 21/500
# Screening paper 22/500
# Screening paper 23/500
# Screening paper 24/500
# Screening paper 25/500
# Screening paper 26/500
# Screening paper 27/500
# Screening paper 28/500
# Screening paper 29/500
# Screening paper 30/500
# Screening paper 31/500
# Screening paper 32/500
# Screening paper 33/500
# Screening paper 34/500
# Screening paper 35/500
# Screening paper 36/500
# Screening paper 37/500
# Screening paper 38/500
# Screening paper 39/500
# Screening paper 40/500
# Screening paper 41/500
# Screening paper 42/500
# Screening paper 43/500
# Screening paper 44/500
# Screening paper 45/500
# Screening paper 46/500
# Screening paper 47/500
# Screening paper 48/500
# Screening paper 49/500
# Screening paper 50/500
# Screening paper 51/500
# Screening paper 52/500
# Screening paper 53/500
# Screening paper 54/500
# Screening paper 55/500
# Screening paper 56/500
# Screening paper 57/500
# Screening paper 58/500
# Screening paper 59/500
# Screening paper 60/500
# Screening paper 61/500
# Screening paper 62/500
# Screening paper 63/500
# Screening paper 64/500
# Screening paper 65/500
# Screening paper 66/500
# Screening paper 67/500
# Screening paper 68/500
# Screening paper 69/500
# Screening paper 70/500
# Screening paper 71/500
# Screening paper 72/500
# Screening paper 73/500
# Screening paper 74/500
# Screening paper 75/500
# Screening paper 76/500
# Screening paper 77/500
# Screening paper 78/500
# Screening paper 79/500
# Screening paper 80/500
# Screening paper 81/500
# Screening paper 82/500
# Screening paper 83/500
# Screening paper 84/500
# Screening paper 85/500
# Screening paper 86/500
# Screening paper 87/500
# Screening paper 88/500
# Screening paper 89/500
# Screening paper 90/500
# Screening paper 91/500
# Screening paper 92/500
# Screening paper 93/500
# Screening paper 94/500
# Screening paper 95/500
# Screening paper 96/500
# Screening paper 97/500
# Screening paper 98/500
# Screening paper 99/500
# Screening paper 100/500
# Screening paper 101/500
# Screening paper 102/500
# Screening paper 103/500
# Screening paper 104/500
# Screening paper 105/500
# Screening paper 106/500
# Screening paper 107/500
# Screening paper 108/500
# Screening paper 109/500
# Screening paper 110/500
# Screening paper 111/500
# Screening paper 112/500
# Screening paper 113/500
# Screening paper 114/500
# Screening paper 115/500
# Screening paper 116/500
# Screening paper 117/500
# Screening paper 118/500
# Screening paper 119/500
# Screening paper 120/500
# Screening paper 121/500
# Screening paper 122/500
# Screening paper 123/500
# Screening paper 124/500
# Screening paper 125/500
# Screening paper 126/500
# Screening paper 127/500
# Screening paper 128/500
# Screening paper 129/500
# Screening paper 130/500
# Screening paper 131/500
# Screening paper 132/500
# Screening paper 133/500
# Screening paper 134/500
# Screening paper 135/500
# Screening paper 136/500
# Screening paper 137/500
# Screening paper 138/500
# Screening paper 139/500
# Screening paper 140/500
# Screening paper 141/500
# Screening paper 142/500
# Screening paper 143/500
# Screening paper 144/500
# Screening paper 145/500
# Screening paper 146/500
# Screening paper 147/500
# Screening paper 148/500
# Screening paper 149/500
# Screening paper 150/500
# Screening paper 151/500
# Screening paper 152/500
# Screening paper 153/500
# Screening paper 154/500
# Screening paper 155/500
# Screening paper 156/500
# Screening paper 157/500
# Screening paper 158/500
# Screening paper 159/500
# Screening paper 160/500
# Screening paper 161/500
# Screening paper 162/500
# Screening paper 163/500
# Screening paper 164/500
# Screening paper 165/500
# Screening paper 166/500
# Screening paper 167/500
# Screening paper 168/500
# Screening paper 169/500
# Screening paper 170/500
# Screening paper 171/500
# Screening paper 172/500
# Screening paper 173/500
# Screening paper 174/500
# Screening paper 175/500
# Screening paper 176/500
# Screening paper 177/500
# Screening paper 178/500
# Screening paper 179/500
# Screening paper 180/500
# Screening paper 181/500
# Screening paper 182/500
# Screening paper 183/500
# Screening paper 184/500
# Screening paper 185/500
# Screening paper 186/500
# Screening paper 187/500
# Screening paper 188/500
# Screening paper 189/500
# Screening paper 190/500
# Screening paper 191/500
# Screening paper 192/500
# Screening paper 193/500
# Screening paper 194/500
# Screening paper 195/500
# Screening paper 196/500
# Screening paper 197/500
# Screening paper 198/500
# Screening paper 199/500
# Screening paper 200/500
# Screening paper 201/500
# Screening paper 202/500
# Screening paper 203/500
# Screening paper 204/500
# Screening paper 205/500
# Screening paper 206/500
# Screening paper 207/500
# Screening paper 208/500
# Screening paper 209/500
# Screening paper 210/500
# Screening paper 211/500
# Screening paper 212/500
# Screening paper 213/500
# Screening paper 214/500
# Screening paper 215/500
# Screening paper 216/500
# Screening paper 217/500
# Screening paper 218/500
# Screening paper 219/500
# Screening paper 220/500
# Screening paper 221/500
# Screening paper 222/500
# Screening paper 223/500
# Screening paper 224/500
# Screening paper 225/500
# Screening paper 226/500
# Screening paper 227/500
# Screening paper 228/500
# Screening paper 229/500
# Screening paper 230/500
# Screening paper 231/500
# Screening paper 232/500
# Screening paper 233/500
# Screening paper 234/500
# Screening paper 235/500
# Screening paper 236/500
# Screening paper 237/500
# Screening paper 238/500
# Screening paper 239/500
# Screening paper 240/500
# Screening paper 241/500
# Screening paper 242/500
# Screening paper 243/500
# Screening paper 244/500
# Screening paper 245/500
# Screening paper 246/500
# Screening paper 247/500
# Screening paper 248/500
# Screening paper 249/500
# Screening paper 250/500
# Screening paper 251/500
# Screening paper 252/500
# Screening paper 253/500
# Screening paper 254/500
# Screening paper 255/500
# Screening paper 256/500
# Screening paper 257/500
# Screening paper 258/500
# Screening paper 259/500
# Screening paper 260/500
# Screening paper 261/500
# Screening paper 262/500
# Screening paper 263/500
# Screening paper 264/500
# Screening paper 265/500
# Screening paper 266/500
# Screening paper 267/500
# Screening paper 268/500
# Screening paper 269/500
# Screening paper 270/500
# Screening paper 271/500
# Screening paper 272/500
# Screening paper 273/500
# Screening paper 274/500
# Screening paper 275/500
# Screening paper 276/500
# Screening paper 277/500
# Screening paper 278/500
# Screening paper 279/500
# Screening paper 280/500
# Screening paper 281/500
# Screening paper 282/500
# Screening paper 283/500
# Screening paper 284/500
# Screening paper 285/500
# Screening paper 286/500
# Screening paper 287/500
# Screening paper 288/500
# Screening paper 289/500
# Screening paper 290/500
# Screening paper 291/500
# Screening paper 292/500
# Screening paper 293/500
# Screening paper 294/500
# Screening paper 295/500
# Screening paper 296/500
# Screening paper 297/500
# Screening paper 298/500
# Screening paper 299/500
# Screening paper 300/500
# Screening paper 301/500
# Screening paper 302/500
# Screening paper 303/500
# Screening paper 304/500
# Screening paper 305/500
# Screening paper 306/500
# Screening paper 307/500
# Screening paper 308/500
# Screening paper 309/500
# Screening paper 310/500
# Screening paper 311/500
# Screening paper 312/500
# Screening paper 313/500
# Screening paper 314/500
# Screening paper 315/500
# Screening paper 316/500
# Screening paper 317/500
# Screening paper 318/500
# Screening paper 319/500
# Screening paper 320/500
# Screening paper 321/500
# Screening paper 322/500
# Screening paper 323/500
# Screening paper 324/500
# Screening paper 325/500
# Screening paper 326/500
# Screening paper 327/500
# Screening paper 328/500
# Screening paper 329/500
# Screening paper 330/500
# Screening paper 331/500
# Screening paper 332/500
# Screening paper 333/500
# Screening paper 334/500
# Screening paper 335/500
# Screening paper 336/500
# Screening paper 337/500
# Screening paper 338/500
# Screening paper 339/500
# Screening paper 340/500
# Screening paper 341/500
# Screening paper 342/500
# Screening paper 343/500
# Screening paper 344/500
# Screening paper 345/500
# Screening paper 346/500
# Screening paper 347/500
# Screening paper 348/500
# Screening paper 349/500
# Screening paper 350/500
# Screening paper 351/500
# Screening paper 352/500
# Screening paper 353/500
# Screening paper 354/500
# Screening paper 355/500
# Screening paper 356/500
# Screening paper 357/500
# Screening paper 358/500
# Screening paper 359/500
# Screening paper 360/500
# Screening paper 361/500
# Screening paper 362/500
# Screening paper 363/500
# Screening paper 364/500
# Screening paper 365/500
# Screening paper 366/500
# Screening paper 367/500
# Screening paper 368/500
# Screening paper 369/500
# Screening paper 370/500
# Screening paper 371/500
# Screening paper 372/500
# Screening paper 373/500
# Screening paper 374/500
# Screening paper 375/500
# Screening paper 376/500
# Screening paper 377/500
# Screening paper 378/500
# Screening paper 379/500
# Screening paper 380/500
# Screening paper 381/500
# Screening paper 382/500
# Screening paper 383/500
# Screening paper 384/500
# Screening paper 385/500
# Screening paper 386/500
# Screening paper 387/500
# Screening paper 388/500
# Screening paper 389/500
# Screening paper 390/500
# Screening paper 391/500
# Screening paper 392/500
# Screening paper 393/500
# Screening paper 394/500
# Screening paper 395/500
# Screening paper 396/500
# Screening paper 397/500
# Screening paper 398/500
# Screening paper 399/500
# Screening paper 400/500
# Screening paper 401/500
# Screening paper 402/500
# Screening paper 403/500
# Screening paper 404/500
# Screening paper 405/500
# Screening paper 406/500
# Screening paper 407/500
# Screening paper 408/500
# Screening paper 409/500
# Screening paper 410/500
# Screening paper 411/500
# Screening paper 412/500
# Screening paper 413/500
# Screening paper 414/500
# Screening paper 415/500
# Screening paper 416/500
# Screening paper 417/500
# Screening paper 418/500
# Screening paper 419/500
# Screening paper 420/500
# Screening paper 421/500
# Screening paper 422/500
# Screening paper 423/500
# Screening paper 424/500
# Screening paper 425/500
# Screening paper 426/500
# Screening paper 427/500
# Screening paper 428/500
# Screening paper 429/500
# Screening paper 430/500
# Screening paper 431/500
# Screening paper 432/500
# Screening paper 433/500
# Screening paper 434/500
# Screening paper 435/500
# Screening paper 436/500
# Screening paper 437/500
# Screening paper 438/500
# Screening paper 439/500
# Screening paper 440/500
# Screening paper 441/500
# Screening paper 442/500
# Screening paper 443/500
# Screening paper 444/500
# Screening paper 445/500
# Screening paper 446/500
# Screening paper 447/500
# Screening paper 448/500
# Screening paper 449/500
# Screening paper 450/500
# Screening paper 451/500
# Screening paper 452/500
# Screening paper 453/500
# Screening paper 454/500
# Screening paper 455/500
# Screening paper 456/500
# Screening paper 457/500
# Screening paper 458/500
# Screening paper 459/500
# Screening paper 460/500
# Screening paper 461/500
# Screening paper 462/500
# Screening paper 463/500
# Screening paper 464/500
# Screening paper 465/500
# Screening paper 466/500
# Screening paper 467/500
# Screening paper 468/500
# Screening paper 469/500
# Screening paper 470/500
# Screening paper 471/500
# Screening paper 472/500
# Screening paper 473/500
# Screening paper 474/500
# Screening paper 475/500
# Screening paper 476/500
# Screening paper 477/500
# Screening paper 478/500
# Screening paper 479/500
# Screening paper 480/500
# Screening paper 481/500
# Screening paper 482/500
# Screening paper 483/500
# Screening paper 484/500
# Screening paper 485/500
# Screening paper 486/500
# Screening paper 487/500
# Screening paper 488/500
# Screening paper 489/500
# Screening paper 490/500
# Screening paper 491/500
# Screening paper 492/500
# Screening paper 493/500
# Screening paper 494/500
# Screening paper 495/500
# Screening paper 496/500
# Screening paper 497/500
# Screening paper 498/500
# Screening paper 499/500
# Screening paper 500/500
#
#
# This paper screening took 445.6 seconds
# The screening included 500 papers, out of which 422 were correctly classified
# True positives: 8
# True negatives: 414
# False positives: 70
# False negatives: 8
